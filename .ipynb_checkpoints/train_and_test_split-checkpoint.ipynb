# %%
import tensorflow as tf
tf.enable_eager_execution()

# !sudo rm -f /etc/boto.cfg
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models, optimizers

import saving_train
import loading_ds_train

import loading_ds_test
import saving_test

# %%
## Must be openslide version 3.4.1
from openslide import open_slide, __library_version__ as openslide_version
print(openslide_version)
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "0,1"
# Out:
# 3.4.1

# %%
## Optional: remove sliced images from directory if necessary
# !rm -r 'data'

# %%
training_image_path_list = ['tumor_091.tif', 'tumor_110.tif']

# %%
saving_train.train_part_1(training_image_path_list,num_pixels = 64, num_level = 2)
# Out:
# tumor_091.tif tumor_091_mask.tif
# tumor_110.tif tumor_110_mask.tif

# %%
ds_train, steps_per_epoch_train = loading_ds_train.train_part_2(training_image_path_list)

# %%
## Create sequential model with Imagenet base
conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(128, 128, 3))

conv_base.trainable = False

model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))

# %%
## Compile and train model
model.compile(optimizer=tf.train.AdamOptimizer(),
              loss=tf.keras.losses.sparse_categorical_crossentropy, 
              metrics = ['acc'])
model.summary()

history = model.fit(ds_train, epochs=2, steps_per_epoch=steps_per_epoch_train)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 4, 4, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                262176
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 14,976,930
# Trainable params: 262,242
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/2
# 961/961 [==============================] - 345s 359ms/step - loss: 0.1414 - acc: 0.9488
# Epoch 2/2
# 961/961 [==============================] - 338s 352ms/step - loss: 0.1080 - acc: 0.9629

# %%
## Plot results
print(history.history)

acc = history.history['acc']
loss = history.history['loss']
# val_acc = history.history['val_loss']
# val_loss = history.history['val_acc']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
# plt.plot(epochs, val_acc, 'b-', label = 'Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
# plt.plot(epochs, val_loss, 'b-', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# {'loss': [0.14140626014201563, 0.1080278746297236], 'acc': [0.9487838189386056, 0.9628642039542143]}

# %%
# image from train set
image_path = 'tumor_091.tif'
image_depth, image_width, tumor_mask, tissue_regions, slide_image_test = saving_test.test_part_1(image_path, num_pixels=64, num_level=2)
loading_ds_test.test_part_2(image_path,model,tissue_regions, slide_image_test, tumor_mask, image_depth, image_width)
# Out:
# tumor_091.tif tumor_091_mask.tif
# 0 0
# 0 0
# Precision: 0.4392091415823258
# Recall: 0.8795396433534778
# F1: 0.5858611680369602
# Confusion Matrix:
#            Predicted 0  Predicted 1
# Reality 0     46318056      3259778
# Reality 1       349661      2553045
#            Predicted 0  Predicted 1
# Reality 0    88.257583     6.211403
# Reality 1     0.666268     4.864746

# %%
# new image from test set
image_path = 'tumor_101.tif'
image_depth, image_width, tumor_mask, tissue_regions, slide_image_test = saving_test.test_part_1(image_path, num_pixels=64, num_level=2)
# Out:
# tumor_101.tif tumor_101_mask.tif
# 0 0
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-3b4df4a4c09b> in <module>
#       1 # new image from test set
#       2 image_path = 'tumor_101.tif'
# ----> 3 image_depth, image_width, tumor_mask, tissue_regions, slide_image_test = saving_test.test_part_1(image_path, num_pixels=64, num_level=2)
#
# ~/camelyon-ai/saving_test.py in test_part_1(testing_image_path, num_pixels, num_level)
#     174                              level=num_level,
#     175                              width=width,
# --> 176                              height=height)
#     177
#     178     tumor_mask = read_slide(tumor_mask,
#
# ~/camelyon-ai/saving_test.py in read_slide(slide, x, y, level, width, height, as_float)
#      83 def read_slide(slide, x, y, level, width, height, as_float=False):
#      84     print(x,y)
# ---> 85     im = slide.read_region((x,y), level, (width, height))
#      86     im = im.convert('RGB') # drop the alpha channel
#      87     if as_float:
#
# ~/miniconda3/envs/cam36_aaron/lib/python3.6/site-packages/openslide/__init__.py in read_region(self, location, level, size)
#     221         function is not premultiplied."""
#     222         return lowlevel.read_region(self._osr, location[0], location[1],
# --> 223                 level, size[0], size[1])
#     224
#     225
#
# ~/miniconda3/envs/cam36_aaron/lib/python3.6/site-packages/openslide/lowlevel.py in read_region(slide, x, y, level, w, h)
#     258     buf = (w * h * c_uint32)()
#     259     _read_region(slide, buf, x, y, level, w, h)
# --> 260     return _load_image(buf, (w, h))
#     261
#     262 get_error = _func('openslide_get_error', c_char_p, [_OpenSlide], _check_string)
#
# ~/miniconda3/envs/cam36_aaron/lib/python3.6/site-packages/openslide/lowlevel.py in _load_image(buf, size)
#      63         '''buf must be a mutable buffer.'''
#      64         _convert.argb2rgba(buf)
# ---> 65         return PIL.Image.frombuffer('RGBA', size, buf, 'raw', 'RGBA', 0, 1)
#      66 except ImportError:
#      67     def _load_image(buf, size):
#
# ~/miniconda3/envs/cam36_aaron/lib/python3.6/site-packages/PIL/Image.py in frombuffer(mode, size, data, decoder_name, *args)
#    2447             im = new(mode, (1, 1))
#    2448             im = im._new(
# -> 2449                 core.map_buffer(data, size, decoder_name, None, 0, args)
#    2450                 )
#    2451             im.readonly = 1
#
# MemoryError: Integer overflow in ysize

# %%
loading_ds_test.test_part_2(image_path,model,tissue_regions, slide_image_test, tumor_mask, image_depth, image_width)
